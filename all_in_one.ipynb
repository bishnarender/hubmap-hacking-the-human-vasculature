# %%
# !python tools/prepare_data.py
# Out:
# (422, 5)
# (339, 5)
# (83, 5)
# (349, 5)
# (73, 5)
# (1211, 5)

# %%
# drop duplicates from dtrain_dataset2.json
# !python tools/drop_duplicates.py
# Out:
# loading annotations into memory...
# Done (t=0.33s)
# creating index...
# index created!
# Image Id "4", annotation id pair (4, 5) => duplicate
# keep annotation ids {0, 1, 2, 3, 4}.
#
# Image Id "12", annotation id pair (1, 6) => duplicate
# Image Id "12", annotation id pair (2, 7) => duplicate
# Image Id "12", annotation id pair (3, 8) => duplicate
# Image Id "12", annotation id pair (0, 9) => duplicate
# Image Id "12", annotation id pair (4, 10) => duplicate
# Image Id "12", annotation id pair (5, 12) => duplicate
# Image Id "12", annotation id pair (11, 13) => duplicate
# keep annotation ids {0, 1, 2, 3, 4, 5, 11}.
#
# Image Id "13", annotation id pair (2, 4) => duplicate
# Image Id "13", annotation id pair (1, 7) => duplicate
# Image Id "13", annotation id pair (0, 8) => duplicate
# Image Id "13", annotation id pair (3, 9) => duplicate
# Image Id "13", annotation id pair (5, 11) => duplicate
# Image Id "13", annotation id pair (6, 12) => duplicate
# ...

# %%
# coco data preparation.
# https://mmsegmentation.readthedocs.io/en/latest/user_guides/2_dataset_prepare.html
# https://github.com/nightrome/cocostuff#downloads

# create folder "data" in "mmdetection-main" (repository from github).

# copy folder train2017 and val2017 (from "http://images.cocodataset.org/zips/train2017.zip" and 
#        http://images.cocodataset.org/zips/val2017.zip) to the location fetched from the file coco_stuff164k.py.

# download data: http://calvin.inf.ed.ac.uk/wp-content/uploads/data/cocostuffdataset/stuffthingmaps_trainval2017.zip
#         and save it to "annotations folder" (folder at the location of train2017 and val2017 folder).

#!python mmdetection-main/tools/dataset_converters/coco_stuff164k.py mmdetection-main/data/stuffthingmaps_trainval2017

# %% [markdown]
# #### Note: before running training, load transforms.py instead of transforms_debug.py in custom_modules/__init__.py

# %%
# !python train.py configs/r0.py --amp
#!python train.py configs/y0.py --amp
#!python train.py configs/m0.py --amp

# https://mmdetection.readthedocs.io/en/latest/user_guides/dataset_prepare.html
#!python train.py configs/coco/s.py --amp # mim install "mmpretrain>=1.0.0rc8" 
#!python train.py configs/s0.py --amp 

#!python train.py configs/coco/sb.py --amp
#!python train.py configs/sb0.py --amp
# Out:
# 08/27 09:31:15 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.17 | packaged by conda-forge | (default, Jun 16 2023, 07:06:00) [GCC 11.4.0]
#     CUDA available: True
#     numpy_random_seed: 533049456
#     GPU 0: NVIDIA GeForce RTX 3050
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
# ...
